# %%
from fastapi import FastAPI
import os 
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
db_url=os.getenv("DB_URL")

app=FastAPI()

# %%
client=MongoClient(db_url)
db_name=client["Honda_cars"]
collection=db_name["listings"]
